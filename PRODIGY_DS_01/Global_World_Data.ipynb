# %% [markdown]
# <b>IMPORTING LIBRARIES</b>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <b>LOADING DATASET</b>

# %%
df = pd.read_csv('world_data_2023.csv')
df.head()
# Out:
#        Country Density\n(P/Km2) Abbreviation Agricultural Land( %)  \
# 0  Afghanistan               60           AF                58.10%
# 1      Albania              105           AL                43.10%
# 2      Algeria               18           DZ                17.40%
# 3      Andorra              164           AD                40.00%
# 4       Angola               26           AO                47.50%
#
#   Land Area(Km2) Armed Forces size  Birth Rate  Calling Code  \
# 0        652,230           323,000       32.49          93.0
# 1         28,748             9,000       11.78         355.0
# 2      2,381,741           317,000       24.28         213.0
# 3            468               NaN        7.20         376.0
# 4      1,246,700           117,000       40.73         244.0
#
#   Capital/Major City Co2-Emissions  ... Out of pocket health expenditure  \
# 0              Kabul         8,672  ...                           78.40%
# ...

# %%
df.dtypes
# Out:
# Country                                       object
# Density\n(P/Km2)                              object
# Abbreviation                                  object
# Agricultural Land( %)                         object
# Land Area(Km2)                                object
# Armed Forces size                             object
# Birth Rate                                   float64
# Calling Code                                 float64
# Capital/Major City                            object
# Co2-Emissions                                 object
# CPI                                           object
# CPI Change (%)                                object
# Currency-Code                                 object
# Fertility Rate                               float64
# Forested Area (%)                             object
# Gasoline Price                                object
# GDP                                           object
# Gross primary education enrollment (%)        object
# ...

# %% [markdown]
# <b>DATA TYPE CONVERSION</b>

# %%
columns = ['Density\n(P/Km2)','Agricultural Land( %)','Life expectancy','Maternal mortality ratio','Land Area(Km2)','Armed Forces size','Birth Rate','Calling Code','Co2-Emissions','CPI','CPI Change (%)','Fertility Rate','Forested Area (%)','Gasoline Price','GDP','Gross primary education enrollment (%)','Gross tertiary education enrollment (%)','Infant mortality','Minimum wage','Out of pocket health expenditure','Physicians per thousand','Population','Population: Labor force participation (%)','Tax revenue (%)','Total tax rate','Unemployment rate','Urban_population']
columns
# Out:
# ['Density\n(P/Km2)',
#  'Agricultural Land( %)',
#  'Life expectancy',
#  'Maternal mortality ratio',
#  'Land Area(Km2)',
#  'Armed Forces size',
#  'Birth Rate',
#  'Calling Code',
#  'Co2-Emissions',
#  'CPI',
#  'CPI Change (%)',
#  'Fertility Rate',
#  'Forested Area (%)',
#  'Gasoline Price',
#  'GDP',
#  'Gross primary education enrollment (%)',
#  'Gross tertiary education enrollment (%)',
#  'Infant mortality',
#  'Minimum wage',
#  'Out of pocket health expenditure',
#  'Physicians per thousand',
#  'Population',
#  'Population: Labor force participation (%)',
#  'Tax revenue (%)',
#  'Total tax rate',
#  'Unemployment rate',
#  'Urban_population']

# %%
df[columns] = df[columns].applymap(lambda x : float(str(x).replace(',','').replace('%','').replace('$','')))
df.dtypes
# Out:
# Country                                       object
# Density\n(P/Km2)                             float64
# Abbreviation                                  object
# Agricultural Land( %)                        float64
# Land Area(Km2)                               float64
# Armed Forces size                            float64
# Birth Rate                                   float64
# Calling Code                                 float64
# Capital/Major City                            object
# Co2-Emissions                                float64
# CPI                                          float64
# CPI Change (%)                               float64
# Currency-Code                                 object
# Fertility Rate                               float64
# Forested Area (%)                            float64
# Gasoline Price                               float64
# GDP                                          float64
# Gross primary education enrollment (%)       float64
# ...

# %%
df.head()
# Out:
#        Country  Density\n(P/Km2) Abbreviation  Agricultural Land( %)  \
# 0  Afghanistan              60.0           AF                   58.1
# 1      Albania             105.0           AL                   43.1
# 2      Algeria              18.0           DZ                   17.4
# 3      Andorra             164.0           AD                   40.0
# 4       Angola              26.0           AO                   47.5
#
#    Land Area(Km2)  Armed Forces size  Birth Rate  Calling Code  \
# 0        652230.0           323000.0       32.49          93.0
# 1         28748.0             9000.0       11.78         355.0
# 2       2381741.0           317000.0       24.28         213.0
# 3           468.0                NaN        7.20         376.0
# 4       1246700.0           117000.0       40.73         244.0
#
#   Capital/Major City  Co2-Emissions  ...  Out of pocket health expenditure  \
# 0              Kabul         8672.0  ...                              78.4
# ...

# %% [markdown]
# <b>HANDLING MISSING VALUES</b>

# %%
columns_with_missing_values = df.columns[df.isnull().any()]
columns_with_missing_values
# Out:
# Index(['Abbreviation', 'Agricultural Land( %)', 'Land Area(Km2)',
#        'Armed Forces size', 'Birth Rate', 'Calling Code', 'Capital/Major City',
#        'Co2-Emissions', 'CPI', 'CPI Change (%)', 'Currency-Code',
#        'Fertility Rate', 'Forested Area (%)', 'Gasoline Price', 'GDP',
#        'Gross primary education enrollment (%)',
#        'Gross tertiary education enrollment (%)', 'Infant mortality',
#        'Largest city', 'Life expectancy', 'Maternal mortality ratio',
#        'Minimum wage', 'Official language', 'Out of pocket health expenditure',
#        'Physicians per thousand', 'Population',
#        'Population: Labor force participation (%)', 'Tax revenue (%)',
#        'Total tax rate', 'Unemployment rate', 'Urban_population', 'Latitude',
#        'Longitude'],
#       dtype='object')

# %%
numerical_columns = df.select_dtypes(include=['float64'])
numerical_columns = numerical_columns.columns[numerical_columns.isnull().any()]
df[numerical_columns] = df[numerical_columns].fillna(df[numerical_columns].mean())

categorial_columns = df.select_dtypes(include=['object'])
categorial_columns = categorial_columns.columns[categorial_columns.isnull().any()]
df[categorial_columns] = df[categorial_columns].fillna(df[categorial_columns].mode().iloc[0])

missing_values = df.isnull().any()
print(missing_values)
# Out:
# Country                                      False
# Density\n(P/Km2)                             False
# Abbreviation                                 False
# Agricultural Land( %)                        False
# Land Area(Km2)                               False
# Armed Forces size                            False
# Birth Rate                                   False
# Calling Code                                 False
# Capital/Major City                           False
# Co2-Emissions                                False
# CPI                                          False
# CPI Change (%)                               False
# Currency-Code                                False
# Fertility Rate                               False
# Forested Area (%)                            False
# Gasoline Price                               False
# GDP                                          False
# Gross primary education enrollment (%)       False
# ...

# %% [markdown]
# <b>DATA VISUALIZATION</b>

# %% [markdown]
# TOP 10 COUNTRIES WITH HIGHEST AND LOWEST UNEMPLOYMENT RATE

# %%
sorted_df = df.sort_values(by='Unemployment rate' , ascending= False)

top_10_unemployment_countries = sorted_df.head(10)
least_10_unemployment_countries = sorted_df.tail(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 2 , figsize = (14 , 6))

sns.barplot(data=top_10_unemployment_countries , x = 'Country' , y = 'Unemployment rate' , ax=axes[0] , palette='bright')
axes[0].set_title("Top 10 High Unemployment rate Countries")
axes[0].set_xlabel("Country")
axes[0].set_ylabel("Unemployment Rate")
axes[0].set_xticklabels(axes[0].get_xticklabels() , rotation = 45 , ha = 'right')

for index , value in enumerate(top_10_unemployment_countries['Unemployment rate']):
    axes[0].text(index , value , f'{value:.2f}%' , ha ='center' , va = 'bottom' , fontsize = 10 , rotation = 40)


sns.barplot(data=least_10_unemployment_countries , x = 'Country' , y = 'Unemployment rate' , ax=axes[1] , palette='bright')
axes[1].set_title("Top 10 Low Unemployment rate Countries")
axes[1].set_xlabel("Country")
axes[1].set_ylabel("Unemployment Rate")
axes[1].set_xticklabels(axes[1].get_xticklabels() , rotation = 45 , ha = 'right')

for index , value in enumerate(least_10_unemployment_countries['Unemployment rate']):
    axes[1].text(index , value , f'{value:.2f}%' , ha ='center' , va = 'bottom' , fontsize = 10 , rotation = 40)

# %% [markdown]
# <I><b>INSIGHTS</b></I><br><br>
# TOP 10 COUNTRIES WITH HIGHEST UNEMPLOYMENT RATES ARE SHOWN IN LEFT PLOT
# 1) SOUTH AFRICA HAS THE HIGHEST UNEMPLOYMENT RATE AT 28.18%, FOLLOWED BY LESOTHO , SAINT LUCIA.
# 2) THE UNITED STATES OF AMERICA ALSO APPEARS IN THIS LIST WITH RELATIVELY HIGH UNEMPLOYEMNT RATE OF 14.72%.
#
# TOP 10 COUNTRIES WITH LOWEST UNEMPLOYMENT RATES ARE SHOWN IN RIGHT PLOT
# 1) THESE COUNTRIES HAVE LOWEST UNEMPLOYMENT RATES , WITH SOME EVEN LESS THAN 1% .
# 2) QATAR HAS THE LOWEST UNEMPLOYMENT RATE AT 0.09%, FOLLOWED BY NIGER , SOLOMON ISLANDS , LAOS ETC...

# %% [markdown]
# TOP 10 COUNTRIES WITH HIGHEST AND LOWEST POPULATION

# %%
sorted_df = df.sort_values(by='Population' , ascending= False)

high_populated_countries = sorted_df.head(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = ( 8 , 6))

sns.barplot(data=high_populated_countries , x = 'Population' , y = 'Country' , ax=axes , palette='gist_rainbow_r')
axes.set_title("Top 10 High Populated Countries")
axes.set_xlabel("Population")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(high_populated_countries['Population']):
    axes.text(value + 1, index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <b><i>INSIGHTS</i></b><br><br>
#
# THE PLOT DISPLAYS THE TOP 10 COUNTRIES WITH THE HIGHEST POPULATIONS.<BR>
# CHINA AND INDIA ARE THE TWO POPULATED COUNTRIES WITH ALMOST 1.4 BILLION POPULATION , FOLLOWED BY UNITED STATES WITH APPROX.. 320 MILLION POPULATION.

# %%
sorted_df = df.sort_values(by='Population' , ascending= False)

low_populated_countries = sorted_df.tail(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8 , 6))

sns.barplot(data=low_populated_countries , x = 'Population' , y = 'Country' , ax=axes , palette='gist_rainbow_r')
axes.set_title("Top 10 Low Populated Countries")
axes.set_xlabel("Population")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(low_populated_countries['Population']):
    axes.text(value + 1, index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# THIS PLOT DISPLAYS TOP 10 COUNTRIES WITH LOWEST POPULATION.<BR>
# COUNTRIES LIKE VATICAN CITY , NAURA , TUVALU , PALAU HAVE POPULATION LESS THAN 20K.

# %% [markdown]
# TOP 10 COUNTRIES WITH HIGHEST AND LOWEST BIRTH RATE

# %%
sorted_df = df.sort_values(by='Birth Rate' , ascending= False)

High_birth_rate = sorted_df.head(10)


fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8 , 6))

sns.barplot(data=High_birth_rate , x = 'Country' , y = 'Birth Rate' , ax=axes , palette='bright')
axes.set_title("High Birth Rate Countries")
axes.set_xlabel("Country")
axes.set_ylabel("Birth Rate")
axes.set_xticklabels(axes.get_xticklabels() , rotation = 45 , ha = 'right')

for index , value in enumerate(High_birth_rate['Birth Rate']):
    plt.text(index , value , f'{value :.2f}' , ha = 'center' , va = 'bottom' , fontsize = 10 , rotation = 45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <I><B>INSIGHTS</I></B><BR><BR>
# THIS VISUALIZATION HIGHLIGHTS TOP 10 COUNTRIES WITH HIGHEST BIRTH RATE.<BR>
# NIGER HAS THE HIGHEST BIRTH RATE OF APPROX. 46 BIRTHS PER 1000 PERSON FOLLOWED BY MALI , UGANDA.

# %%
sorted_df = df.sort_values(by='Birth Rate' , ascending= False)

low_birth_rate = sorted_df.tail(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=low_birth_rate , x = 'Country' , y = 'Birth Rate' , ax=axes , palette='gist_rainbow_r')
axes.set_title("Low Birth Rate Countries")
axes.set_xlabel("Country")
axes.set_ylabel("Birth Rate")
axes.set_xticklabels(axes.get_xticklabels() , rotation = 45 , ha = 'right')

for index , value in enumerate(low_birth_rate['Birth Rate']):
    plt.text(index , value , f'{value:.2f}' , ha = 'center' , va = 'bottom' , fontsize = 10 , rotation = 45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <I><B>INSIGHTS</I></B><BR><BR>
#
# THIS PLOT SHOWS COUNTRIES WITH LOWEST BIRTH RATE.<BR>
# MONACO , SOUTH KOREA , SAN MARINO ARE THE COUNTRIES WITH LEAST BIRTH RATES.

# %% [markdown]
# TOP 10 COUNTRIES WITH HIGHEST AGRICULTURAL LAND

# %%
sorted_df = df.sort_values(by='Agricultural Land( %)' , ascending= False)

high_agri_land = sorted_df.head(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (12,6))
sns.barplot(data=high_agri_land , x = 'Country' , y = 'Agricultural Land( %)' , ax=axes , palette='cool_r')
axes.set_title("Countries with High Agricultural Land")
axes.set_xlabel("Country")
axes.set_ylabel("Agricultural Land (%)")
axes.set_yticklabels(['{:,}'.format(int(x)) for x in axes.get_yticks()] , rotation = 45 , ha = 'right')
plt.xticks(rotation = 40)

for index , value in enumerate(high_agri_land['Agricultural Land( %)']):
    plt.text(index , value , f'{value:.2f}%' , ha = 'center' , va ='bottom' , fontsize = 10 , rotation = 45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# THE PLOT HIGHLIGHTS THE COUNTRIES WITH HIGHEST AGRICULTURAL LAND AREA , URUGUAY IS THE COUNTRY WITH HIGHEST AGRICULTURAL LAND OF 82.60% , FOLLOWED BY SAUDI ARABIA , KAZAKHSTAN.

# %% [markdown]
# TOP 10 COUNTRIES WITH LOWEST AGRICULTURAL LAND

# %%
sorted_df = df.sort_values(by='Agricultural Land( %)' , ascending= False)

low_agri_land = sorted_df.tail(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (16,6))
sns.barplot(data=low_agri_land , x = 'Country' , y = 'Agricultural Land( %)' , ax=axes , palette='cool_r')
axes.set_title("Countries with Low Agricultural Land")
axes.set_xlabel("Country")
axes.set_ylabel("Agricultural Land (%)")
plt.xticks(rotation = 45)

axes.set_yticklabels(['{:,}'.format(int(x)) for x in axes.get_yticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(low_agri_land['Agricultural Land( %)']):
    plt.text(index , value , f'{value:.2f}%' , ha = 'center' , va = 'bottom' , fontsize = 10 , rotation = 45)

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# COUNTRIES WITH THE LOWEST AGRICULTURAL LAND AREA IS SURINAME WITH 0.60% LAND , SINGAPORE 0.90% AND SO ON...

# %% [markdown]
# TOP 10 COUNTRIES WITH LARGEST ARMED FORCES

# %%
sorted_df = df.sort_values(by='Armed Forces size' , ascending= False)

largest_armed_force = sorted_df.head(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=largest_armed_force , y = 'Country' , x = 'Armed Forces size' , ax=axes , palette='bright')
axes.set_title("Countries with Largest Armed Force Size")
axes.set_xlabel("Number of Armed Force")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(largest_armed_force['Armed Forces size']):
    axes.text(value + 1, index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# THE PLOT REFLECTS THE COUNTRY WITH LARGEST ARMED FORCE SIZE .<BR>
# INDIA , WITH 30LAKHS NUMBER OF ARMED FORCE IS THE FIRST COUNTRY , FOLLOWED BY CHINA AND NORTH KOREA.

# %% [markdown]
# TOP 10 COUNTRIES WITH LOWEST ARMED FORCES

# %%
sorted_df = df.sort_values(by='Armed Forces size' , ascending= False)

smallest_armed_force = sorted_df.tail(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=smallest_armed_force , y = 'Country' , x = 'Armed Forces size' , ax=axes , palette='bright')
axes.set_title("Countries with Smallest Armed Force Size")
axes.set_xlabel("Number of Armed Force")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(smallest_armed_force['Armed Forces size']):
    axes.text(value , index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# COUNTRIES LIKE LIBYA , ICELAND , HAITI DOES NOT HAVE ARMED FORCE

# %% [markdown]
# TOP 10 COUNTRIES WITH LARGEST LAND AREAS

# %%
sorted_df = df.sort_values(by='Land Area(Km2)' , ascending= False)

largest_land_area = sorted_df.head(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=largest_land_area , y = 'Country' , x = 'Land Area(Km2)' , ax=axes , palette='gist_rainbow_r')
axes.set_title("Countries with Largest Land Area(Km2)")
axes.set_xlabel("Land Area(Km2)")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(largest_land_area['Land Area(Km2)']):
    axes.text(value + 1, index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# THE PLOT SHOWS TOP 10 COUNTRIES WITH HIGHEST LAND AREA .<BR>
# RUSSIA AS THE LEADER WITH THE HIGHEST LAND AREA , FOLLOWED BY CANADA AND UNITED STATES OF AMERICA

# %% [markdown]
# TOP 10 COUNTRIES WITH SMALLEST LAND AREAS

# %%
sorted_df = df.sort_values(by='Land Area(Km2)' , ascending= False)

smallest_land_area = sorted_df.tail(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=smallest_land_area , y = 'Country' , x = 'Land Area(Km2)' , ax=axes , palette='gist_rainbow_r')
axes.set_title("Countries with Smallest Land Area(Km2)")
axes.set_xlabel("Land Area(Km2)")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(smallest_land_area['Land Area(Km2)']):
    axes.text(value + 1, index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# THE PLOT SHOWS THE COUNTRIES WITH LOWEST LAND AREA (KM2).<BR>

# %% [markdown]
# TOP 10 COUNTRIES WITH HIGHEST CO2 EMISSIONS

# %%
sorted_df = df.sort_values(by='Co2-Emissions' , ascending= False)

high_co2_emission = sorted_df.head(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (10,6))
sns.barplot(data=high_co2_emission , y = 'Country' , x = 'Co2-Emissions' , ax=axes , palette='cool_r')
axes.set_title("Countries with Highest Co2-Emissions")
axes.set_xlabel("Co2 - Emissions")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(high_co2_emission['Co2-Emissions']):
    axes.text(value + 1, index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
# THIS PLOT SHOWS COUNTRIES WITH HIGHEST CO2 - EMISSIONS <BR>
# CHINA TOPPED THIS PLOT AS BEING THE COUNTRY WITH HIGHEST CO2-EMISSIONS , FOLLOWED BY UNITED STATES AND INDIA.

# %% [markdown]
# TOP 10 COUNTRIES WITH LOWEST CO2 EMISSIONS

# %%
sorted_df = df.sort_values(by='Co2-Emissions' , ascending= False)

low_co2_emission = sorted_df.tail(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=low_co2_emission , y = 'Country' , x = 'Co2-Emissions' , ax=axes , palette='cool_r')
axes.set_title("Countries with Lowest Co2-Emissions")
axes.set_xlabel("Co2 - Emissions")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(low_co2_emission['Co2-Emissions']):
    axes.text(value + 1, index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# TUVALU IS THE COUNTRY WITH LOWEST C02 - EMISSIONS

# %% [markdown]
# TOP 10 COUNTRIES WITH HIGH INFANT MORTALITY

# %%
sorted_df = df.sort_values(by='Infant mortality' , ascending= False)

high_infant_mortality = sorted_df.head(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=high_infant_mortality , y = 'Country' , x = 'Infant mortality' , ax=axes , palette='cool_r')
axes.set_title("Countries with High Infant Mortality")
axes.set_xlabel("Infant Mortality")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(high_infant_mortality['Infant mortality']):
    axes.text(value + 1, index , f'{value:.0f}' , va = 'center')
plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# HIGH INFANT MORTALITY RATES(BETWEEN 50 - 80) REVEAL HEALTH CARE CONDITIONS AMONG THE TOP 10 COUNTRIES.<BR>
# URGENT ACTION AND INTERNATIONAL COLLABORATION NEEDED TO IMPROVE CONDITIONS.

# %% [markdown]
# TOP 10 COUNTRIES WITH LOW INFANT MORTALITY

# %%
sorted_df = df.sort_values(by='Infant mortality' , ascending= False)

low_infant_mortality = sorted_df.tail(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=low_infant_mortality , y = 'Country' , x = 'Infant mortality' , ax=axes , palette='cool_r')
axes.set_title("Countries with Low Infant Mortality")
axes.set_xlabel("Infant Mortality")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(low_infant_mortality['Infant mortality']):
    axes.text(value , index , f'{value:.0f}' , va = 'center')
plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>

# %% [markdown]
# TOP 10 COUNTRIES WITH HIGHEST GDP

# %%
sorted_df = df.sort_values(by='GDP' , ascending= False)

high_GDP = sorted_df.head(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=high_GDP , y = 'Country' , x = 'GDP' , ax=axes , palette='bright')
axes.set_title("Countries with High GDP")
axes.set_xlabel("GDP")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(high_GDP['GDP']):
    axes.text(value , index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# A BAR GRAPH ILLUSTRATE THEIR GDP(GROSS DOMESTIC PRODUCT) VALUES RANGING FROM BILLIONS TO TRILLIONS , SHOWCASING LEADING ECONOMY'S.<BR>
# THE USA LEADS WITH THE HIGHEST GDP, FOLLOWED BY CHINA , JAPAN , GERMANY.

# %% [markdown]
# TOP 10 COUNTRIES WITH LOWEST GDP

# %%
sorted_df = df.sort_values(by='GDP' , ascending= False)

low_GDP = sorted_df.tail(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (8,6))
sns.barplot(data=low_GDP , y = 'Country' , x = 'GDP' , ax=axes , palette='bright')
axes.set_title("Countries with Low GDP")
axes.set_xlabel("GDP")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(low_GDP['GDP']):
    axes.text(value  , index , f'{value:.0f}' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# TUVALU IS THE COUNTRY WITH LOWEST GDP GROWTH

# %% [markdown]
# TOP 10 COUNTRIES WITH HIGHEST TERTIARY EDUCATION ENROLLMENT RATES

# %%
sorted_df = df.sort_values(by='Gross tertiary education enrollment (%)' , ascending= False)

high_tert_edu = sorted_df.head(10)

fig , axes = plt.subplots(nrows= 1 , ncols= 1 , figsize = (10,6))
sns.barplot(data=high_tert_edu , y = 'Country' , x = 'Gross tertiary education enrollment (%)' , ax=axes , palette='viridis')
axes.set_title("Countries with Highest Tertiary Education Enrollment (%)")
axes.set_xlabel("Tertiary Education Enrollment (%)")
axes.set_ylabel("Country")
axes.set_xticklabels(['{:,}'.format(int(x)) for x in axes.get_xticks()] , rotation = 45 , ha = 'right')

for index , value in enumerate(high_tert_edu['Gross tertiary education enrollment (%)']):
    axes.text(value+1 , index , f'{value:.2f}%', va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# GREECE HOLDS THE HIGHEST RATE OF 136.60% , FOLLOWED BY AUSTRALIA , GRENADA , SOUTH KOREA.<BR>
# THIS BAR SHOWS THE SIGNIFICANT DISPARITIES IN TERTIARY EDUCATION ENROLLMENT ACROSS THE COUNTRIES , SHOWCASING THEIR DEDICATION TOWARDS EDUCATION.

# %% [markdown]
# TOP 10 CPI CHANGE (%) : CURRENCY CODE

# %%
top_cur = 10
top_currencies = df.nlargest(top_cur , 'CPI Change (%)')

plt.figure(figsize=(8,6))
sns.barplot(x = 'CPI Change (%)' , y = 'Currency-Code' , data=top_currencies , palette='viridis')
plt.title("Top CPI Change (%) by Currency-Code")
plt.xlabel("CPI Change (%)")
plt.ylabel("Currency Code")
plt.xticks(rotation = 45)

for index , value in enumerate(top_currencies['CPI Change (%)']):
    plt.text(value , index , f'{value:.2f}%' , va = 'center')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
# A BAR GRAPH DISPLAYS THESE CHANGES, RANGING FROM 22% - 254.90%, REVEALING THEIR ECONOMIC TRENDS AND VARIATION AMONG CURRENCIES.<BR>
# COUNTRIES WITH HIGHEST POSITIVE CPI CHANGES MIGHT SUGGEST INFLATIONARY PRESSURE AND ECONOMIC GROWTH , WHEREAS NEGATIVE CHANGES COULD REFLECT DEFLATIONARY CONCERNS.

# %% [markdown]
# URBANIZATION TRENDS BY COUNTRY

# %%
countries = 10
urbanization_trend_by_countries = df.groupby('Country')['Urban_population'].mean().sort_values(ascending= False).head(countries)

plt.figure(figsize=(10,8))
ax = urbanization_trend_by_countries.plot(kind = 'barh' , color = 'skyblue')
plt.title("Urbanization Trends by Country")
plt.xlabel("Average Urban Population")
plt.ylabel("Country")
plt.gca().invert_yaxis()

for index , value in enumerate(urbanization_trend_by_countries):
    ax.text(value , index , f'{value:.2f}' , va = 'center' , color = 'black')

plt.tight_layout()
plt.show()

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# NOTABLE ENTRIES INCLUDE CHINA WITH 842 MILLION , INDIA WITH ABOUT 472 MILLION , AND THE UNITED STATES WITH APPROXIMATELY 270 MILLION URBAN INHABITANTS.

# %% [markdown]
# POPULATION DENSITY DISTRIBUTION

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Density\n(P/Km2)'] , bins = 20 ,color='Orange',edgecolor = 'red')
plt.title("Population Density Distribution")
plt.xlabel("Population Density")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# THE HISTOGRAM DEPICTS THAT HIGHER NUMBER OF COUNTRIES HAVE RELATIVELY LOWER POPULATION DENSITIES , WHILE FEWER COUNTRIES HAVE HIGHER DENSITIES EXCEEDING 1000 PEOPLE PER SQUARE KILOMETER

# %% [markdown]
# DISTRIBUTION OF LIFE EXPECTANCY

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Life expectancy'] , bins = 20 , kde = True , color='Orange')
plt.title("Life expectancy Distribution")
plt.xlabel("Life Expectancy")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# THE DISTRIBUTION OF LIFE EXPECTANCY IS SKEWED TO LEFT, WITH A PEAK OF AROUND 75-80 YEARS.<BR>
# MOST COUNTRIES HAVE LIFE EXPECTANCIES BETWEEN 60 TO 85 YEARS.

# %% [markdown]
# DISTRIBUTION OF BIRTH RATES

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Birth Rate'] , bins = 25 , kde = True)
plt.title("Birth Rates Distribution")
plt.xlabel("Birth Rates")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# THE DISTRIBUTION IS RIGHT SKEWED WITH FEWER COUNTRIES HAVING HIGHER BIRTH RATES AND LARGER PROPORTION HAVING LOWER BIRTH RATES.

# %% [markdown]
# URBAN POPULATION DISTRIBUTION

# %%
plt.figure(figsize=(8,6))
sns.histplot(df['Urban_population'] , bins = 25 , kde = True)
plt.title("Urban Population Distribution")
plt.xlabel("Urban Population")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# <i><b>INSIGHTS</i></b><br><br>
#
# THE URBAN POPULATION DISTRIBUTION EXHIBITS RIGHT-SKEWED PATTERN , WITH A HIGHER CONCENTRATION OF COUNTRIES HAVING SMALL URBAN POPULATION.
